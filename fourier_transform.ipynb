# %% [markdown]
# ## Import Libraries and Initial Setup

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("drive/MyDrive/bear.jpg", 0)
img2 = cv2.imread("drive/MyDrive/cute_octopus.jpg", 0)

# %% [markdown]
# ### Fourier Transform in OpenCV
# "OpenCV provides the functions cv.dft() and cv.idft() for this. It returns the same result as previous, but with two channels. First channel will have the real part of the result and second channel will have the imaginary part of the result." -OpenCv Documentation

# %%
dft = cv2.dft(np.float32(img), flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 10*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
dft2 = cv2.dft(np.float32(img2), flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift2 = np.fft.fftshift(dft2)

magnitude_spectrum2 = 10*np.log(cv2.magnitude(dft_shift2[:,:,0],dft_shift2[:,:,1]))

plt.subplot(121),plt.imshow(img2, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum2, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.imshow(10*np.log(cv2.magnitude(dft2[:,:,0],dft2[:,:,1])),cmap="gray");

# %%
plt.imshow(10*np.log(cv2.magnitude(dft_shift2[:,:,0],dft_shift2[:,:,1])),cmap="gray");

# %% [markdown]
# ### Inverse Fourier Transform

# %%
f_inverse_shift = np.fft.ifftshift(dft_shift)
img_back = cv2.idft(f_inverse_shift)
# img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
img_back = np.sqrt((img_back[:,:,0]**2)+(img_back[:,:,1]**2))
plt.imshow(img_back,cmap="gray");

# %%
f_inverse_shift2 = np.fft.ifftshift(dft_shift2)
img_back2 = cv2.idft(f_inverse_shift2)
# img_back = cv2.magnitude(img_back2[:,:,0],img_back2[:,:,1])
img_back2 = np.sqrt((img_back2[:,:,0]**2)+(img_back2[:,:,1]**2))
plt.imshow(img_back2,cmap="gray");
